# %% [markdown]
# <a href="https://colab.research.google.com/github/samanthajmichael/machine_learning/blob/main/notebooks/Transfer_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **DSBA 6165 Applied Machine Learning**
# # Transfer Learning Lab
#
# Professor: Rick Chakra
#
# TA: Spencer Tilley

# %% [markdown]
# #Big Idea
# In practice, very few people train an entire Convolutional Network from scratch (with random initialization), because it is relatively rare to have a dataset of sufficient size. Instead, it is common to pretrain a ConvNet on a very large dataset (e.g. ImageNet, which contains 1.2 million images with 1000 categories), and then use the ConvNet either as an initialization or a fixed feature extractor for the task of interest.

# %% [markdown]
# #These two major transfer learning scenarios look as follows:
#
# **Finetuning the ConvNet:** Instead of random initialization, we initialize the network with a pretrained network, like the one that is trained on imagenet 1000 dataset. Rest of the training looks as usual.
#
# **ConvNet as fixed feature extractor:**Here, we will freeze the weights for all of the network except that of the final fully connected layer. This last fully connected layer is replaced with a new one with random weights and only this layer is trained.

# %% [markdown]
# Import packages, including datasets, models, and transformations from torchvision

# %%
# License: BSD
# Author: Sasank Chilamkurthy

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms # using torchvision datasets and pretrained models
import matplotlib.pyplot as plt
import time
import os
from PIL import Image
from tempfile import TemporaryDirectory

cudnn.benchmark = True
plt.ion()   # interactive mode - plot gets dynamically updated

# %% [markdown]
# #Load Data
#
# We will use torchvision and torch.utils.data packages for loading the data.
#
# The problem we’re going to solve today is to train a model to classify ants and bees. We have about 120 training images each for ants and bees. There are 75 validation images for each class. Usually, this is a very small dataset to generalize upon, if trained from scratch. Since we are using transfer learning, we should be able to generalize reasonably well.
#
# This dataset is a very small subset of imagenet.

# %%
# get data
# !wget https://download.pytorch.org/tutorial/hymenoptera_data.zip
# Out:
# --2024-12-04 18:48:14--  https://download.pytorch.org/tutorial/hymenoptera_data.zip
# Resolving download.pytorch.org (download.pytorch.org)... 3.167.192.10, 3.167.192.5, 3.167.192.62, ...
# Connecting to download.pytorch.org (download.pytorch.org)|3.167.192.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 47286322 (45M) [application/zip]
# Saving to: ‘hymenoptera_data.zip’
#
# hymenoptera_data.zi 100%[===================>]  45.10M   234MB/s    in 0.2s
#
# 2024-12-04 18:48:14 (234 MB/s) - ‘hymenoptera_data.zip’ saved [47286322/47286322]

# %%
# unzip data
# !unzip hymenoptera_data.zip
# Out:
# Archive:  hymenoptera_data.zip
#    creating: hymenoptera_data/
#    creating: hymenoptera_data/train/
#    creating: hymenoptera_data/train/ants/
#   inflating: hymenoptera_data/train/ants/0013035.jpg
#   inflating: hymenoptera_data/train/ants/1030023514_aad5c608f9.jpg
#   inflating: hymenoptera_data/train/ants/1095476100_3906d8afde.jpg
#   inflating: hymenoptera_data/train/ants/1099452230_d1949d3250.jpg
#   inflating: hymenoptera_data/train/ants/116570827_e9c126745d.jpg
#   inflating: hymenoptera_data/train/ants/1225872729_6f0856588f.jpg
#   inflating: hymenoptera_data/train/ants/1262877379_64fcada201.jpg
#   inflating: hymenoptera_data/train/ants/1269756697_0bce92cdab.jpg
#   inflating: hymenoptera_data/train/ants/1286984635_5119e80de1.jpg
#   inflating: hymenoptera_data/train/ants/132478121_2a430adea2.jpg
#   inflating: hymenoptera_data/train/ants/1360291657_dc248c5eea.jpg
#   inflating: hymenoptera_data/train/ants/1368913450_e146e2fb6d.jpg
# ...

# %%
# Dataset
# dataloader
# model
# training loop

# %%
# Data augmentation and normalization for training
# Just normalization for validation
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(224), ## this is where we set the parameter to the # of images we want to crop out
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]) ## make sure the data is normalized the same way the original model was
    ]),
    'val': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

data_dir = 'hymenoptera_data'
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=4,
                                             shuffle=True, num_workers=4) # num_workers - this can be a bottleneck
              for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
class_names = image_datasets['train'].classes

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(

# %% [markdown]
# #Visualize a few images
#
# Let’s visualize a few training images so as to understand the data augmentations.

# %%
# the way pytorch views data is different than everything else - [b,c,H,W] - height width channel - batch, channel, height, weight]
#cannot plot this data - it has to look like [H,W,c]

# %%
def imshow(inp, title=None):
    """Display image for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0)) ## have to transpose to get the data into the right dimensions for visualization - un-normalize the image
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated


# Get a batch of training data
inputs, classes = next(iter(dataloaders['train']))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes]) ## these are the cropped images

# %% [markdown]
# #Training the model
#
# Now, let’s write a general function to train a model. Here, we will illustrate:
#
# Scheduling the learning rate.
# Saving the best model.
# In the following, parameter scheduler is an LR scheduler object from torch.optim.lr_scheduler.

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25): ## criteron - loss function
    since = time.time()

    # Create a temporary directory to save training checkpoints
    with TemporaryDirectory() as tempdir:
        best_model_params_path = os.path.join(tempdir, 'best_model_params.pt')

        torch.save(model.state_dict(), best_model_params_path) ## state dictionary - model structure and all it's weights
        best_acc = 0.0

        for epoch in range(num_epochs):
            print(f'Epoch {epoch}/{num_epochs - 1}')
            print('-' * 10)

            # Each epoch has a training and validation phase
            for phase in ['train', 'val']:
                if phase == 'train':
                    model.train()  # Set model to training mode - turns on the dropouts and gradients
                else:
                    model.eval()   # Set model to evaluate mode - turns off the dropouts and gradients

                running_loss = 0.0
                running_corrects = 0

                # Iterate over data.
                for inputs, labels in dataloaders[phase]:
                    inputs = inputs.to(device)
                    labels = labels.to(device)

                    # zero the parameter gradients - every training loop you zero out the gradients.
                    optimizer.zero_grad()

                    # forward
                    # track history if only in train
                    with torch.set_grad_enabled(phase == 'train'):
                        outputs = model(inputs)
                        _, preds = torch.max(outputs, 1) # out of all the outputs it picks the one with the highest value
                        loss = criterion(outputs, labels)

                        # backward + optimize only if in training phase
                        if phase == 'train':
                            loss.backward() ## back propagation when we are training the model
                            optimizer.step()

                    # statistics
                    running_loss += loss.item() * inputs.size(0)
                    running_corrects += torch.sum(preds == labels.data)
                if phase == 'train': # if training at the end of the first epoch - step the scheduler - shifts the lr one step smaller
                    scheduler.step()

                epoch_loss = running_loss / dataset_sizes[phase]
                epoch_acc = running_corrects.double() / dataset_sizes[phase]

                print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

                # save the model with the best accuracy
                if phase == 'val' and epoch_acc > best_acc:
                    best_acc = epoch_acc
                    torch.save(model.state_dict(), best_model_params_path)

            print()

        time_elapsed = time.time() - since
        print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
        print(f'Best val Acc: {best_acc:4f}')

        # load best model weights
        model.load_state_dict(torch.load(best_model_params_path))
    return model

# %%
#### To save your model with the epochs and other criteria to be reloaded
# torch.save({
#     'epoch': epoch,
#     'model_state_dict': model.state_dict(),
#     'optimizer_state_dict': optimizer.state_dict(),
#     'loss': loss,
#     # You can add any other training info you want to save
# }, f'checkpoint_epoch_{epoch}.pth')

# %%
#### To load your model
# checkpoint = torch.load('checkpoint_epoch_X.pth')
# model.load_state_dict(checkpoint['model_state_dict'])
# optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
# epoch = checkpoint['epoch']
# loss = checkpoint['loss']

# %% [markdown]
# #Visualizing the model predictions
#
# Generic function to display predictions for a few images

# %%
def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title(f'predicted: {class_names[preds[j]]}')
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %% [markdown]
# #1. Finetuning the ConvNet
#
# Load a pretrained model and reset final fully connected layer. Resnet18 is 18 layers. Residual - deep networks - vanishing gradient overtime even if you do all the things right. The residual (error) skips connections so it doesn't shrink over time.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
## average pooling - second to last layer

# %%
model_ft = models.resnet18(weights='IMAGENET1K_V1')
num_ftrs = model_ft.fc.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to ``nn.Linear(num_ftrs, len(class_names))``.
model_ft.fc = nn.Linear(num_ftrs, 2)

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size = 7, gamma=0.1)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 96.6MB/s]

# %% [markdown]
# #Train and evaluate
#
# It should take around 15-25 min on CPU. On GPU though, it takes less than a minute.

# %%
model_ft = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=25)
# Out:
# Epoch 0/24
# ----------
# train Loss: 0.6103 Acc: 0.6516
# val Loss: 0.4380 Acc: 0.8366
#
# Epoch 1/24
# ----------
# train Loss: 0.6308 Acc: 0.7705
# val Loss: 0.9504 Acc: 0.7190
#
# Epoch 2/24
# ----------
# train Loss: 0.6533 Acc: 0.8115
# val Loss: 0.3831 Acc: 0.8824
#
# Epoch 3/24
# ----------
# train Loss: 0.5349 Acc: 0.7992
# val Loss: 0.3396 Acc: 0.8627
#
# Epoch 4/24
# ----------
# train Loss: 0.4784 Acc: 0.7951
# val Loss: 0.6018 Acc: 0.7974
#
# Epoch 5/24
# ----------
# train Loss: 0.5827 Acc: 0.7828
# val Loss: 0.4409 Acc: 0.8170
#
# Epoch 6/24
# ----------
# train Loss: 0.5324 Acc: 0.7910
# val Loss: 0.5046 Acc: 0.8366
#
# Epoch 7/24
# ----------
# train Loss: 0.4560 Acc: 0.7951
# val Loss: 0.2574 Acc: 0.8758
#
# Epoch 8/24
# ----------
# train Loss: 0.2655 Acc: 0.9057
# val Loss: 0.2536 Acc: 0.8889
#
# Epoch 9/24
# ----------
# train Loss: 0.2600 Acc: 0.8893
# val Loss: 0.2404 Acc: 0.9085
#
# Epoch 10/24
# ----------
# train Loss: 0.3746 Acc: 0.8361
# ...

# %%
visualize_model(model_ft)

# %% [markdown]
# #2. Using the pretrained ConvNet as fixed feature extractor
#
# Here, we need to freeze all the network except the final layer. We need to set requires_grad = False to freeze the parameters so that the gradients are not computed in backward().

# %%
model_conv = torchvision.models.resnet18(weights='IMAGENET1K_V1')
for param in model_conv.parameters():
    param.requires_grad = False

# Parameters of newly constructed modules have requires_grad=True by default
num_ftrs = model_conv.fc.in_features
model_conv.fc = nn.Linear(num_ftrs, 2) ## hard coding the last layer to tell it how many neurons are coming in and how many outputs you need.

model_conv = model_conv.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that only parameters of final layer are being optimized as
# opposed to before.
optimizer_conv = optim.SGD(model_conv.fc.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_conv, step_size=7, gamma=0.1)

# %%
from torchsummary import summary
summary(model_ft, input_size=(3, 224, 224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1         [-1, 64, 112, 112]           9,408
#        BatchNorm2d-2         [-1, 64, 112, 112]             128
#               ReLU-3         [-1, 64, 112, 112]               0
#          MaxPool2d-4           [-1, 64, 56, 56]               0
#             Conv2d-5           [-1, 64, 56, 56]          36,864
#        BatchNorm2d-6           [-1, 64, 56, 56]             128
#               ReLU-7           [-1, 64, 56, 56]               0
#             Conv2d-8           [-1, 64, 56, 56]          36,864
#        BatchNorm2d-9           [-1, 64, 56, 56]             128
#              ReLU-10           [-1, 64, 56, 56]               0
#        BasicBlock-11           [-1, 64, 56, 56]               0
#            Conv2d-12           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-13           [-1, 64, 56, 56]             128
# ...

# %% [markdown]
# #Train and evaluate
#
# On CPU this will take about half the time compared to previous scenario. This is expected as gradients don’t need to be computed for most of the network. However, forward does need to be computed.

# %%
model_conv = train_model(model_conv, criterion, optimizer_conv,
                         exp_lr_scheduler, num_epochs=25)
# Out:
# Epoch 0/24
# ----------
# train Loss: 0.5322 Acc: 0.7213
# val Loss: 0.2333 Acc: 0.9477
#
# Epoch 1/24
# ----------
# train Loss: 0.4861 Acc: 0.7787
# val Loss: 0.3029 Acc: 0.8889
#
# Epoch 2/24
# ----------
# train Loss: 0.3765 Acc: 0.8361
# val Loss: 0.2011 Acc: 0.9477
#
# Epoch 3/24
# ----------
# train Loss: 0.4998 Acc: 0.7664
# val Loss: 0.1622 Acc: 0.9608
#
# Epoch 4/24
# ----------
# train Loss: 0.3749 Acc: 0.8238
# val Loss: 0.2685 Acc: 0.8954
#
# Epoch 5/24
# ----------
# train Loss: 0.4327 Acc: 0.8402
# val Loss: 0.3454 Acc: 0.8693
#
# Epoch 6/24
# ----------
# train Loss: 0.3945 Acc: 0.7828
# val Loss: 0.1618 Acc: 0.9477
#
# Epoch 7/24
# ----------
# train Loss: 0.3395 Acc: 0.8566
# val Loss: 0.2039 Acc: 0.9216
#
# Epoch 8/24
# ----------
# train Loss: 0.3063 Acc: 0.8770
# val Loss: 0.1662 Acc: 0.9542
#
# Epoch 9/24
# ----------
# train Loss: 0.4053 Acc: 0.8115
# val Loss: 0.1835 Acc: 0.9412
#
# Epoch 10/24
# ----------
# train Loss: 0.3288 Acc: 0.8443
# ...

# %%
from torchsummary import summary
summary(model_conv, input_size=(3, 224, 224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1         [-1, 64, 112, 112]           9,408
#        BatchNorm2d-2         [-1, 64, 112, 112]             128
#               ReLU-3         [-1, 64, 112, 112]               0
#          MaxPool2d-4           [-1, 64, 56, 56]               0
#             Conv2d-5           [-1, 64, 56, 56]          36,864
#        BatchNorm2d-6           [-1, 64, 56, 56]             128
#               ReLU-7           [-1, 64, 56, 56]               0
#             Conv2d-8           [-1, 64, 56, 56]          36,864
#        BatchNorm2d-9           [-1, 64, 56, 56]             128
#              ReLU-10           [-1, 64, 56, 56]               0
#        BasicBlock-11           [-1, 64, 56, 56]               0
#            Conv2d-12           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-13           [-1, 64, 56, 56]             128
# ...

# %%
visualize_model(model_conv)

plt.ioff()
plt.show()

# %% [markdown]
# #Inference on custom images
#
# Use the trained model to make predictions on custom images and visualize the predicted class labels along with the images.

# %%
def visualize_model_predictions(model,img_path):
    was_training = model.training
    model.eval()

    img = Image.open(img_path)
    img = data_transforms['val'](img)
    img = img.unsqueeze(0)
    img = img.to(device)

    with torch.no_grad():
        outputs = model(img)
        _, preds = torch.max(outputs, 1)

        ax = plt.subplot(2,2,1)
        ax.axis('off')
        ax.set_title(f'Predicted: {class_names[preds[0]]}')
        imshow(img.cpu().data[0])

        model.train(mode=was_training)

# %%
# visualize_model_predictions(
#     model_conv,
#     img_path = 'ant.jpg' # upload custom image of ants / bees
# )

# plt.ioff()
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-22-78108d4ee534> in <cell line: 1>()
# ----> 1 visualize_model_predictions(
#       2     model_conv,
#       3     img_path = 'ant.jpg' # upload custom image of ants / bees
#       4 )
#       5
#
# <ipython-input-21-b3ba80b4fddd> in visualize_model_predictions(model, img_path)
#       3     model.eval()
#       4
# ----> 5     img = Image.open(img_path)
#       6     img = data_transforms['val'](img)
#       7     img = img.unsqueeze(0)
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    3467
#    3468     if filename:
# -> 3469         fp = builtins.open(filename, "rb")
#    3470         exclusive_fp = True
#    3471     else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/ant.jpg'
